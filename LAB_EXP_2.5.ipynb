# %% [markdown]
# <a href="https://colab.research.google.com/github/4wsjad/DATA-MODELING-AND-VISUALIZATION/blob/main/LAB_EXP_2.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
#load datasetn
df= pd.read_csv("/content/titanic3.csv")
#extract specific columns as Numpy arrays
ages = df['age'].values
fares = df['fare'].values
survived = df['survived'].values
#statistical analysis
mean_fare = np.mean(fares)
median_fare = np. median(fares)
std_age = np.nanstd(ages) #nanstd ignores missing NaN values
youngest = np.nanmin(ages)
highest_fare = np.max(fares)
#filter fares of survived vs deceased passengers
survived_mask= (survived == 1)
mean_fare_survived = np.mean(fares[survived_mask])
mean_fare_deceased = np.mean(fares[~survived_mask])
pclass = df['pclass'].values
child_first_class_mask=(ages<18)&(pclass==1)
total_count=np.sum(child_first_class_mask)
